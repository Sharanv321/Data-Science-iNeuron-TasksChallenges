# %%
import pandas as pd

# %%
# 1. Read this dataset in pandas , mysql and mongodb

# %%
df = pd.read_csv("FitBit Data.csv")

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   04-08-2016       23014      20.389999        20.389999
# 453  8877689391   04-09-2016       16470       8.070000         8.070000
# 454  8877689391   04-10-2016       28497      27.530001        27.530001
# 455  8877689391   04-11-2016       10622       8.060000         8.060000
# 456  8877689391   04-12-2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
# 3. convert all the dates avaible in dataset to timestamp format in pandas

# %%
df['ActivityDate'] = df['ActivityDate'].apply(lambda x: pd.Timestamp(x).strftime('%B-%d-%Y %I:%M %p'))

# %%
df.head(2)
# Out:
#            Id            ActivityDate  TotalSteps  TotalDistance  \
# 0  1503960366  March-25-2016 12:00 AM       11004           7.11
# 1  1503960366  March-26-2016 12:00 AM       17609          11.55
#
#    TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 0             7.11                       0.0                2.57
# 1            11.55                       0.0                6.92
#
#    ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 0                      0.46                 4.07                      0.0
# 1                      0.73                 3.91                      0.0
#
#    VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# 0                 33                   12                   205
# 1                 89                   17                   274
#
#    SedentaryMinutes  Calories
# 0               804      1819
# 1               588      2154

# %%
# 4. Find out in this data that how many unique id's we have

# %%
array1 = df['Id'].unique()

# %%
array1  # It gives the list of unique ids
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
len(array1)  # This gives the total no of unique ids in an array
# Out:
# 35

# %%
# 5. which id is one of the active id that you have in whole dataset

# %%
df['Id'].max()    # It gives the maximum occurance of the id (active id)
# Out:
# 8877689391

# %%
# 6 . how many of them have not logged there activity find out in terms of number of ids

# %%
df5 = df.loc[df['LoggedActivitiesDistance'] == 0]

# %%
df5.count()
# Out:
# Id                          433
# ActivityDate                433
# TotalSteps                  433
# TotalDistance               433
# TrackerDistance             433
# LoggedActivitiesDistance    433
# VeryActiveDistance          433
# ModeratelyActiveDistance    433
# LightActiveDistance         433
# SedentaryActiveDistance     433
# VeryActiveMinutes           433
# FairlyActiveMinutes         433
# LightlyActiveMinutes        433
# SedentaryMinutes            433
# Calories                    433
# dtype: int64

# %% [markdown]
# 433 ids have not logged their activity in the LoggedActivitiesDistance column

# %%
# 7. Find out who is the laziest person id that we have in dataset

# %%
df2 = df.groupby('Id',as_index=False)['SedentaryMinutes'].sum()

# %%
df2['SedentaryMinutes'].max()
# Out:
# 43458

# %%
df2[df2['SedentaryMinutes'] == df2['SedentaryMinutes'].max()]
# Out:
#             Id  SedentaryMinutes
# 14  4057192912             43458

# %% [markdown]
# Id 4.057193e+09	 is the most laziest as this id has most sedentary minutes (43458.0)

# %%
# 8. xplore over an internet that how much calories burn is required for a 
# healthy person and find out how many healthy person we have in our dataset

# %%
# From the internet, i have taken daily burn of calories between 2000 to 2500 is healthy.
# So, in the query i have given the range between 2000 to 2500 calories

# %%
df6 = df[(df['Calories']>=2000) & (df['Calories'] <= 2500)]

# %%
df6
# Out:
#              Id            ActivityDate  TotalSteps  TotalDistance  \
# 1    1503960366  March-26-2016 12:00 AM       17609          11.55
# 10   1503960366  April-04-2016 12:00 AM       14557           9.80
# 11   1503960366  April-05-2016 12:00 AM       14844           9.73
# 41   1644430081  April-04-2016 12:00 AM        2819           2.05
# 62   1927972279  April-03-2016 12:00 AM        3198           2.21
# ..          ...                     ...         ...            ...
# 433  8792009665  April-01-2016 12:00 AM        4592           2.94
# 436  8792009665  April-04-2016 12:00 AM        3821           2.45
# 437  8792009665  April-05-2016 12:00 AM        2332           1.49
# 438  8792009665  April-06-2016 12:00 AM        2121           1.36
# 442  8792009665  April-10-2016 12:00 AM        4605           2.95
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 1              11.55                       0.0                6.92
# ...

# %% [markdown]
# 121 people spend daily calories in the range of 2000 to 2500. They are healthy

# %%
# 9. how many person are not a regular person with respect to activity try to find out those

# %%
# By regular, those who have more attendence to the gym
# people who are least regular have least attendence to the gym

# %%
df15 = df.groupby('Id',as_index=False)['ActivityDate'].count()

# %%
df15.sort_values('ActivityDate')
# Out:
#             Id  ActivityDate
# 32  8583815059             8
# 10  2891001357             8
# 16  4388161847             8
# 25  6775888955             9
# 24  6391747486             9
# 2   1644430081            10
# 23  6290855005            10
# 22  6117666160            10
# 11  3372868164            10
# 21  5577150313            11
# 29  8053475328            11
# 34  8877689391            12
# 20  5553957443            12
# 28  7086361926            12
# 18  4558609924            12
# 33  8792009665            12
# 30  8253242879            12
# 12  3977333714            12
# 9   2873212765            12
# 31  8378563200            12
# 7   2320127002            12
# 6   2026352035            12
# 5   2022484408            12
# 4   1927972279            12
# 3   1844505072            12
# 15  4319703577            12
# 27  7007744171            12
# 26  6962181067            14
# 17  4445114986            15
# 8   2347167796            15
# 19  4702921684            15
# ...

# %% [markdown]
# The above query gives ids and their total count from the Activity dates (that is, how many days they attended the gym.)
# It start from the lowest attendence of 8 days to the highest of 32 days. From this we can judge who is more regular to gym,
# who is least regular to gym, who is average regular to the gym.

# %%
# 10 . who is the third most active person in this dataset find out those in pandas and in sql both

# %%
df11 = df.VeryActiveMinutes.nlargest(3).iloc[-1]

# %%
df11
# Out:
# 128

# %%
df[df['VeryActiveMinutes'] == df.VeryActiveMinutes.nlargest(3).iloc[-1]]
# Out:
#              Id            ActivityDate  TotalSteps  TotalDistance  \
# 454  8877689391  April-10-2016 12:00 AM       28497      27.530001
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 454        27.530001                       0.0               21.92
#
#      ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 454                      1.12                 4.46                      0.0
#
#      VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# 454                128                   46                   211
#
#      SedentaryMinutes  Calories
# 454              1055      4526

# %% [markdown]
# 8877689391 is the third most active person in this dataset

# %%
# 11 . who is the 5th most laziest person avilable in dataset find it out

# %%
df10 = df.groupby('Id',as_index=False)['SedentaryMinutes'].sum()

# %%
df10.SedentaryMinutes.nlargest(5).iloc[-1]
# Out:
# 15387

# %%
df10[df10['SedentaryMinutes'] == df10.SedentaryMinutes.nlargest(5).iloc[-1]]
# Out:
#            Id  SedentaryMinutes
# 0  1503960366             15387

# %% [markdown]
# 1503960366 is 5th most laziest person, who has total 15387 SedentaryMinutes

# %%
# 12 . what is a total acumulative calories burn for a person find out

# %%
df13 = df.groupby('Id',as_index=False)['Calories'].sum()

# %%
df13
# Out:
#             Id  Calories
# 0   1503960366     34128
# 1   1624580081     25705
# 2   1644430081     29164
# 3   1844505072     19391
# 4   1927972279     27048
# 5   2022484408     29704
# 6   2026352035     16266
# 7   2320127002     18385
# 8   2347167796     30320
# 9   2873212765     20349
# 10  2891001357     18187
# 11  3372868164     18603
# 12  3977333714     16777
# 13  4020332650     98412
# 14  4057192912     60913
# 15  4319703577     23931
# 16  4388161847     14442
# 17  4445114986     31617
# 18  4558609924     21962
# 19  4702921684     42322
# 20  5553957443     21630
# 21  5577150313     36303
# 22  6117666160     20993
# 23  6290855005     21656
# 24  6391747486     15868
# 25  6775888955     24523
# 26  6962181067     29249
# 27  7007744171     31525
# 28  7086361926     26124
# 29  8053475328     31825
# 30  8253242879     17556
# 31  8378563200     40274
# 32  8583815059     19130
# 33  8792009665     24884
# 34  8877689391     41414
