# %%
import pandas as pd

# %%
# 1. Read this dataset in pandas , mysql and mongodb

# %%
df_orders = pd.read_excel("Superstore_USA.xlsx","Orders")

# %%
df_orders.head(1)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88            0.5            2
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
#
#     Region State or Province     City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois  Addison        60101 2012-05-28 2012-05-30
#
#   Profit  Quantity ordered new Sales Order ID
# 0   1.32                     2   5.9    88525
#
# [1 rows x 24 columns]

# %%
df_returns = pd.read_excel("Superstore_USA.xlsx","Returns")

# %%
df_returns.head(1)
# Out:
#    Order ID    Status
# 0        65  Returned

# %%
df_users = pd.read_excel("Superstore_USA.xlsx","Users")

# %%
df_users.head(1)
# Out:
#     Region Manager
# 0  Central   Chris

# %%
# 3 . Find out how return that we ahve recived and with a product id

# %% [markdown]
# I have noticed, the issue is with the dataset. There is no matching row between Returns(Order ID) and Orders(Order ID),
# Hence, it will not yield any result. However, i have written my code. If there was any matching Order ID, it would have given some output

# %%
df_orders_returns = pd.merge(df_orders,df_returns,on='Order ID',how='left')

# %%
result = df_orders_returns[~df_orders_returns['Status'].isna()]

# %%
result
# Out:
# Empty DataFrame
# Columns: [Row ID, Order Priority, Discount, Unit Price, Shipping Cost, Customer ID, Customer Name, Ship Mode, Customer Segment, Product Category, Product Sub-Category, Product Container, Product Name, Product Base Margin, Region, State or Province, City, Postal Code, Order Date, Ship Date, Profit, Quantity ordered new, Sales, Order ID, Ship Date-Order Date, Status]
# Index: []
#
# [0 rows x 26 columns]

# %%
result[['Product Name','Order ID','Status']]
# Out:
# Empty DataFrame
# Columns: [Product Name, Order ID, Status]
# Index: []

# %%
# 4 . try  to join order and return data both in sql and pandas

# %% [markdown]
# Same above code written for question no 3 for pandas part.

# %%
# 5. Try to find out how many unique customer that we have

# %%
array1 = df_orders['Customer ID'].unique()

# %%
array1  # It gives the list of unique customer ID
# Out:
# array([   2,    3,    5, ..., 3400, 3402, 3403], dtype=int64)

# %%
len(array1)  # This gives the total no of unique customer ids in an array
# Out:
# 2703

# %% [markdown]
# There are 2703 unique customer IDs

# %%
# 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region

# %%
df_users['Region'].count()
# Out:
# 4

# %% [markdown]
# There are 4 regions

# %%
df_users
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
# 7. find out how many different shipement mode that we have and 
# what is a percentage usablity of all the shipment mode with respect to dataset

# %%
array2 = df_orders['Ship Mode'].unique()

# %%
array2
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
len(array2)
# Out:
# 3

# %% [markdown]
# There are 3 different shipment mode we have. those are 'Regular Air', 'Express Air', 'Delivery Truck

# %%
df2 = df_orders.groupby('Ship Mode')['Row ID'].agg(['count'])

# %%
df2
# Out:
#                 count
# Ship Mode
# Delivery Truck   1283
# Express Air      1107
# Regular Air      7036

# %%
df2['%']=100*df2['count']/df2['count'].sum()

# %%
df2
# Out:
#                 count          %
# Ship Mode
# Delivery Truck   1283  13.611288
# Express Air      1107  11.744112
# Regular Air      7036  74.644600

# %% [markdown]
# The above data gives percentage wise distribution of ship mode.
# Regular Air has highest share of 74.6446%,
# followed by Delivery Truck share of 13.611288 %
# followed by Express Air share of 11.744112%

# %%
# 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date",

# %%
df3 = df_orders

# %%
df3['Ship Date-Order Date']=(df3['Ship Date']-df3['Order Date']).dt.days

# %%
df3.head(1)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88            0.5            2
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
#
#   State or Province     City Postal Code  Order Date  Ship Date Profit  \
# 0          Illinois  Addison       60101  2012-05-28 2012-05-30   1.32
#
#   Quantity ordered new  Sales Order ID Ship Date-Order Date
# 0                    2    5.9    88525                    2
#
# [1 rows x 25 columns]

# %%
# 9. base on question number 8 find out for which order id we have shipment duration more than 10 days \n",

# %%
df4 = df3[df3['Ship Date-Order Date']>10]

# %%
df4[['Order ID','Ship Date-Order Date']]
# Out:
#       Order ID  Ship Date-Order Date
# 643      87215                    84
# 1548     86318                    11
# 1549     86318                    15
# 1678     87957                    17
# 1679     87957                    11
# 1680     87957                    28
# 1697     19556                    17
# 1698     19556                    11
# 1699     19556                    28
# 2515     86177                    92
# 5548     88223                    14
# 5673     88352                    17
# 5859     87572                    22
# 5881     91294                    24
# 8607     86434                    18
# 8609     86436                    17
# 8610     86436                    19
# 8973     87300                    19
# 8982     19841                    27
# 8983     19841                    31
# 8993     19841                    19
# 8996     87300                    27
# 8997     87300                    31

# %% [markdown]
# Above data gives the list of orders which have total shipment duration more than 10 days

# %%
# 10 . Try to find out a list of a returned order which sihpment duration was 
# more then 15 days and find out that region manager as well ",

# %%
df4 = df3[df3['Ship Date-Order Date']>15]

# %%
df4
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5673   19005            Low      0.06       65.99           2.50         2088
# 5859   24392            Low      0.05       29.89           1.99         2143
# 5881   21257            Low      0.05        7.99           5.03         2153
# 8607   26351         Medium      0.00        8.32           2.38         3119
# 8609   26350         Medium      0.07      180.98          55.24         3119
# ...

# %%
# 11 . Group by region and find out which region is more profitable \n",

# %%
df6 = df_orders.groupby('Region')['Profit'].agg(['sum'])

# %%
df6
# Out:
#                    sum
# Region
# Central  519825.567067
# East     377566.186045
# South    104201.192420
# West     310849.453897

# %% [markdown]
# South region is more profitable as it has made highest total profit of 2319.8903

# %%
# 12 . Try to find out overalll in which country we are giving more discount \n",

# %% [markdown]
# There is no column name as country in the dataset. We can find out more discount given either in a particular region, state or city.

# %%
df_orders.groupby('Region')['Discount'].agg(['sum'])
# Out:
#             sum
# Region
# Central  143.06
# East     114.45
# South     96.53
# West     113.75

# %% [markdown]
# West region has given more discount.

# %%
df_orders.groupby('State or Province')['Discount'].agg(['sum'])
# Out:
#                         sum
# State or Province
# Alabama                5.87
# Arizona                6.86
# Arkansas               5.80
# California            52.28
# Colorado               8.05
# Connecticut            4.28
# Delaware               0.66
# District of Columbia   3.10
# Florida               26.38
# Georgia                9.79
# Idaho                  5.57
# Illinois              29.71
# Indiana               12.22
# Iowa                   7.15
# Kansas                 6.89
# Kentucky               4.23
# Louisiana              4.86
# Maine                  6.66
# Maryland               8.85
# Massachusetts         11.22
# Michigan              15.29
# Minnesota             12.52
# Mississippi            3.89
# Missouri               8.09
# Montana                2.39
# Nebraska               3.59
# Nevada                 1.80
# New Hampshire          2.62
# New Jersey             8.73
# New Mexico             4.08
# New York              28.86
# ...

# %% [markdown]
# New York state has given more discount

# %%
df_orders.groupby('City')['Discount'].agg(['sum'])
# Out:
#              sum
# City
# Aberdeen    0.32
# Abilene     0.22
# Abington    0.08
# Acton       0.00
# Addison     0.23
# ...          ...
# York        0.21
# Youngstown  0.33
# Yuba City   0.01
# Yucaipa     0.15
# Yuma        0.18
#
# [1424 rows x 1 columns]

# %% [markdown]
# Santa Clara and Seattle cities have given more discounts

# %%
# 13 . Give me a list of unique postal code

# %%
array5 = df_orders['Postal Code'].unique()

# %%
len(array5)
# Out:
# 1697

# %%
array5
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %% [markdown]
# There are 13 unique postal codes. they are 55423., 47401., 95051., 98119., 94061., 57006., 10550.,
#        20151., 91104., 32839., 70458., 10112., 12306

# %%
# 14 . which customer segement is more profitalble find it out . \n",

# %%
df14 = df_orders.groupby('Customer Segment')['Profit'].agg(['sum'])

# %%
df14
# Out:
#                             sum
# Customer Segment
# Consumer          206559.625348
# Corporate         505538.627783
# Home Office       283869.553814
# Small Business    316474.592482

# %% [markdown]
# Corporate segment is more profitable with profit of 505538.627783

# %%
# 15 . try to find out the 10th most loss making product catagory . \n",

# %%
df15 = df_orders.sort_values('Product Base Margin',ascending=False).drop_duplicates('Product Name').sort_index()

# %%
df15['Product Base Margin'].nsmallest(n=10)
# Out:
# 157     0.35
# 380     0.35
# 424     0.35
# 1118    0.35
# 1140    0.35
# 1153    0.35
# 1157    0.35
# 1711    0.35
# 1888    0.35
# 1989    0.35
# Name: Product Base Margin, dtype: float64

# %% [markdown]
# Above data gives smallest top 10 Product Name, Product Base Margins

# %%
# 16 . Try to find out 10 top  product with highest margins \n",

# %%
df16 = df_orders.sort_values('Product Base Margin',ascending=False).drop_duplicates('Product Name').sort_index()

# %%
df16['Product Base Margin'].nlargest(n=10)
# Out:
# 230     0.85
# 3994    0.85
# 4168    0.85
# 4756    0.85
# 9145    0.85
# 2847    0.84
# 2879    0.84
# 9283    0.84
# 165     0.83
# 242     0.83
# Name: Product Base Margin, dtype: float64

# %% [markdown]
# Above data gives top 10 Product Name, Product Base Margins
